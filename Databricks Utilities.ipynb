# %%
dbutils.help()

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.combobox("top_n_records",
                         defaultValue=1,
                         choices=["1","2","3","4"],
                         label="Top N Records")

# %%
dbutils.widgets.combobox("top_n_records",
                         defaultValue="1",
                         choices=["1","2","3","4"],
                         label="Top N Records")

# %%
dbutils.widgets.get("top_n_records")

# %% [markdown]
# #####diif in combobox and drodown is you can't type any value in drowdown which not in list whenre combox do

# %%
dbutils.widgets.dropdown("env",
                         defaultValue="DEV",
                         choices=["DEV","PP","PROD"],
                         label="Envs")

# %%
dbutils.widgets.get("env")

# %%
dbutils.widgets.multiselect("choices",
                         defaultValue="2G",
                         choices=["2G","3G","4G"],
                         label="Tech")

# %%
dbutils.widgets.remove("top_n_records")

# %%
dbutils.widgets.removeAll()

# %%
dbutils.notebook.help()

# %%
execution_status=dbutils.notebook.run("./childNotebook01",timeout_seconds=15)
execution_status

# %%
execution_status = dbutils.notebook.run("./childNotebook01", timeout_seconds=100, arguments={
    "environment": "Testing"
})
execution_status
