# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_catalog.quickstart_schema.users_new")

# %%
# %sql
 
DESCRIBE FORMATTED quickstart_catalog.quickstart_schema.users_new;

# %%
# %sql

SELECT * FROM quickstart_catalog.quickstart_schema.users_new LIMIT 4

# %% [markdown]
# #Give error if no of columns are not matching in new file that you want to append

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_catalog.quickstart_schema.users_new", mode="append")

# %% [markdown]
# #Use merge schema is allow to append data even second file is having more columns

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema", "true").saveAsTable(
    "quickstart_catalog.quickstart_schema.users_new", mode="append"
)

# %%
from pyspark.sql.functions import col
 
spark.read.table("quickstart_catalog.quickstart_schema.users_new").filter(
    col("id") <= 4
).limit(4).display()

from pyspark.sql.functions import col
 
spark.read.table("quickstart_catalog.quickstart_schema.users_new").filter(
    col("id") > 2500
).limit(4).display()

# %%
# if less column it got insertd with matchSchema even as inserted other coluns as null
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_012_less_columns.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_catalog.quickstart_schema.users_new", mode="append")

# %%
from pyspark.sql.functions import col
 
spark.read.table("quickstart_catalog.quickstart_schema.users_new").filter(
    col("id") >= 5501
).limit(4).display()

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,
).select(col("user_id").alias("id"), col("full_name").alias("name")).write.saveAsTable(
    "quickstart_catalog.quickstart_schema.users_new", mode="append"
)
